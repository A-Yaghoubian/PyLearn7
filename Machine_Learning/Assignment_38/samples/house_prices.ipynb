# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([110, 175, 65, 70, 20, 200, 150, 80])
Y = np.array([40, 400, 30, 35, 25, 500, 55, 37])

# %%
plt.scatter(X, Y)
plt.show()

# %%
X = np.random.random(100) * 200 + 15
Y = X * 2 + np.random.random(100) * 0.3 * 200
plt.scatter(X, Y)
plt.show()
